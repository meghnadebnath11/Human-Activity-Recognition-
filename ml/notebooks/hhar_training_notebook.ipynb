# %% [markdown]
# # HHAR Training Notebook
#
# This notebook mirrors the command-line training pipeline for the UCI HHAR project.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[1]
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

PROJECT_ROOT

# %%
from ml.src.train import main

# Run the same pipeline used by the CLI.
# Adjust the command-line parser defaults in ml/src/train.py if needed.
# For notebook use, call the script from a terminal for explicit flags.
